# %% [markdown]
# # Customer Service Pipeline Exercise
#
# **Sequential Flow**: Classify Agent → Process Agent → Respond Agent
#
# This exercise demonstrates:
# - Three specialized agents for support workflow
# - Ticket classification and routing
# - Context gathering and personalized responses

# %%
from strands import Agent, tool
from strands.models import BedrockModel
import json

# %% [markdown]
# ## Define Support Tools

# %%
@tool
def get_customer_history(customer_id: str) -> str:
    """Retrieve customer account history and previous interactions"""
    history = {
        "customer_id": customer_id,
        "account_status": "Premium",
        "member_since": "2023-05-15",
        "total_orders": 24,
        "lifetime_value": 3450,
        "previous_tickets": [
            {"date": "2025-11-20", "issue": "Shipping delay", "status": "Resolved"},
            {"date": "2025-09-10", "issue": "Product question", "status": "Resolved"}
        ]
    }
    return json.dumps(history)

@tool
def get_order_details(order_id: str) -> str:
    """Retrieve specific order information"""
    order = {
        "order_id": order_id,
        "date": "2025-12-15",
        "status": "Shipped",
        "tracking": "1Z999AA10123456784",
        "items": ["Wireless Headphones", "USB-C Cable"],
        "total": 149.99,
        "estimated_delivery": "2025-12-20"
    }
    return json.dumps(order)

@tool
def search_knowledge_base(query: str) -> str:
    """Search internal knowledge base for solutions"""
    results = {
        "query": query,
        "articles": [
            {"title": "How to track your order", "url": "kb/track-order"},
            {"title": "Return policy guide", "url": "kb/returns"},
            {"title": "Shipping timeframes", "url": "kb/shipping"}
        ]
    }
    return json.dumps(results)

# %% [markdown]
# ## Step 1: Create Classify Agent
#
# **Purpose**: Categorize support tickets by type, priority, and urgency

# %%
classify_agent = Agent(
    name="classify_agent",
    system_prompt="""You are a support ticket classification specialist.
    
    Your role:
    - Categorize tickets into: Billing, Shipping, Product, Technical, Account, Other
    - Assign priority: Low, Medium, High, Urgent
    - Identify sentiment: Positive, Neutral, Negative, Angry
    - Extract key entities: customer_id, order_id, product_name
    - Flag if escalation needed
    
    Output format (JSON):
    {
      "category": "[category]",
      "priority": "[priority]",
      "sentiment": "[sentiment]",
      "entities": {"customer_id": "...", "order_id": "..."},
      "escalate": true/false,
      "summary": "[one sentence summary]"
    }""",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0")
)

# %% [markdown]
# ## Step 2: Create Process Agent
#
# **Purpose**: Gather relevant context, history, and supporting information

# %%
process_agent = Agent(
    name="process_agent",
    system_prompt="""You are a support context specialist.
    
    Your role:
    - Use tools to gather customer history, order details, and knowledge base articles
    - Compile all relevant context for the ticket
    - Identify potential solutions from knowledge base
    - Note any special customer considerations (VIP, previous issues, etc.)
    
    Output format:
    ## Customer Context
    [Customer history and status]
    
    ## Issue Context
    [Order/product details if applicable]
    
    ## Relevant Solutions
    [Knowledge base articles and recommendations]
    
    ## Special Notes
    [Any important considerations]""",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0"),
    tools=[get_customer_history, get_order_details, search_knowledge_base]
)

# %% [markdown]
# ## Step 3: Create Respond Agent
#
# **Purpose**: Draft personalized, empathetic customer response

# %%
respond_agent = Agent(
    name="respond_agent",
    system_prompt="""You are a customer service response specialist.
    
    Your role:
    - Draft personalized, empathetic responses
    - Address the customer by name if available
    - Acknowledge their concern with empathy
    - Provide clear, actionable solutions
    - Include relevant links or next steps
    - Match tone to customer sentiment (more empathy for negative sentiment)
    - Keep response concise but complete (150-250 words)
    
    Response structure:
    1. Greeting with personalization
    2. Empathetic acknowledgment
    3. Clear solution or explanation
    4. Next steps or additional help
    5. Professional closing""",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0")
)

# %% [markdown]
# ## Step 4: Implement Sequential Workflow

# %%
def customer_service_pipeline(ticket: str) -> dict:
    """
    Execute sequential customer service pipeline.
    
    Args:
        ticket: Customer support ticket text
    
    Returns:
        Dictionary with outputs from each stage
    """
    print("=" * 60)
    print("STAGE 1: TICKET CLASSIFICATION")
    print("=" * 60)
    
    # Stage 1: Classify the ticket
    classification = classify_agent(f"Classify this support ticket:\n\n{ticket}")
    print(classification)
    
    print("\n" + "=" * 60)
    print("STAGE 2: CONTEXT PROCESSING")
    print("=" * 60)
    
    # Stage 2: Gather context
    process_prompt = f"""Gather all relevant context for this ticket:
    
TICKET:
{ticket}

CLASSIFICATION:
{classification}
"""
    context = process_agent(process_prompt)
    print(context)
    
    print("\n" + "=" * 60)
    print("STAGE 3: RESPONSE GENERATION")
    print("=" * 60)
    
    # Stage 3: Generate response
    response_prompt = f"""Draft a customer response for this ticket:
    
ORIGINAL TICKET:
{ticket}

CLASSIFICATION:
{classification}

CONTEXT:
{context}
"""
    response = respond_agent(response_prompt)
    print(response)
    
    return {
        "classification": str(classification),
        "context": str(context),
        "response": str(response)
    }

# %% [markdown]
# ## Step 5: Test with Realistic Tickets

# %%
# Test Case 1: Shipping inquiry
ticket1 = """
Subject: Where is my order?
From: sarah.johnson@email.com
Customer ID: CUST-12345
Order ID: ORD-98765

Hi, I ordered wireless headphones on December 15th and haven't received them yet. 
The tracking shows it's still in transit but it was supposed to arrive by December 20th. 
Can you help me figure out what's going on?
"""

result = customer_service_pipeline(ticket1)
# Out:
# ============================================================
# STAGE 1: TICKET CLASSIFICATION
# ============================================================
# {
#   "category": "Shipping",
#   "priority": "Medium",
#   "sentiment": "Neutral",
#   "entities": {
#     "customer_id": "CUST-12345",
#     "order_id": "ORD-98765"
#   },
#   "escalate": false,
#   "summary": "A customer is inquiring about the status and delay of their in-transit order of wireless headphones."
# }{
#   "category": "Shipping",
#   "priority": "Medium",
#   "sentiment": "Neutral",
#   "entities": {
#     "customer_id": "CUST-12345",
#     "order_id": "ORD-98765"
#   },
#   "escalate": false,
#   "summary": "A customer is inquiring about the status and delay of their in-transit order of wireless headphones."
# }
#
#
# ============================================================
# STAGE 2: CONTEXT PROCESSING
# ============================================================
# <thinking>To gather all relevant context for this ticket, I need to use the provided customer ID and order ID to retrieve the customer's history, order details, and any relevant knowledge base articles. Here is the plan:
#
# 1. Retrieve the customer's history using the customer ID.
# 2. Retrieve the specific order details using the order ID.
# 3. Search for relevant knowledge base articles related to order tracking and delays.
#
# Once I have all the necessary information, I can compile the context and identify potential solutions.</thinking>
#
#
# Tool #1: get_customer_history
#
# Tool #2: get_order_details
#
# Tool #3: search_knowledge_base
# ## Customer Context
# - **Customer ID**: CUST-12345
# - **Account Status**: Premium
# - **Member Since**: 2023-05-15
# - **Total Orders**: 24
# - **Lifetime Value**: $3450
# - **Previous Tickets**:
#   - **2025-11-20**: Shipping delay (Resolved)
#   - **2025-09-10**: Product question (Resolved)
#
# ## Issue Context
# - **Order ID**: ORD-98765
# - **Date**: 2025-12-15
# - **Status**: Shipped
# - **Tracking**: 1Z999AA10123456784
# - **Items**: Wireless Headphones, USB-C Cable
# - **Total**: $149.99
# - **Estimated Delivery**: 2025-12-20
#
# ## Relevant Solutions
# - **"How to track your order"** (URL: kb/track-order)
# - **"Return policy guide"** (URL: kb/returns)
# - **"Shipping timeframes"** (URL: kb/shipping)
#
# ## Special Notes
# - The customer has a premium account status, indicating a higher level of engagement and possibly higher expectations.
# - There is a history of a previous shipping delay, which may indicate a need for extra attention.
# - The order is currently in transit and was supposed to arrive by December 20th, but the customer has not received it yet.
#
# Based on the gathered information, it seems that the customer's order is in transit, and the delay might be causing concern. I will provide Sarah with the tracking information and suggest she reviews the relevant knowledge base articles to understand the shipping timeframes and what to do if there are further delays. If the issue persists, we can escalate it for further investigation.## Customer Context
# - **Customer ID**: CUST-12345
# - **Account Status**: Premium
# - **Member Since**: 2023-05-15
# - **Total Orders**: 24
# - **Lifetime Value**: $3450
# - **Previous Tickets**:
#   - **2025-11-20**: Shipping delay (Resolved)
#   - **2025-09-10**: Product question (Resolved)
#
# ## Issue Context
# - **Order ID**: ORD-98765
# - **Date**: 2025-12-15
# - **Status**: Shipped
# - **Tracking**: 1Z999AA10123456784
# - **Items**: Wireless Headphones, USB-C Cable
# - **Total**: $149.99
# - **Estimated Delivery**: 2025-12-20
#
# ## Relevant Solutions
# - **"How to track your order"** (URL: kb/track-order)
# - **"Return policy guide"** (URL: kb/returns)
# - **"Shipping timeframes"** (URL: kb/shipping)
#
# ## Special Notes
# - The customer has a premium account status, indicating a higher level of engagement and possibly higher expectations.
# - There is a history of a previous shipping delay, which may indicate a need for extra attention.
# - The order is currently in transit and was supposed to arrive by December 20th, but the customer has not received it yet.
#
# Based on the gathered information, it seems that the customer's order is in transit, and the delay might be causing concern. I will provide Sarah with the tracking information and suggest she reviews the relevant knowledge base articles to understand the shipping timeframes and what to do if there are further delays. If the issue persists, we can escalate it for further investigation.
#
#
# ============================================================
# STAGE 3: RESPONSE GENERATION
# ============================================================
# **Subject:** Update on Your Order Status
#
# **Dear Sarah Johnson,**
#
# Thank you for reaching out to us regarding your order. We understand how important it is to receive your wireless headphones on time, especially since you have a premium account and have had a previous shipping delay.
#
# I have checked the status of your order (ORD-98765) and it is currently in transit with the tracking number 1Z999AA10123456784. Although it was estimated to arrive by December 20th, it seems there may be a delay.
#
# For more information on our shipping timeframes and what to do if there are further delays, you might find the [shipping timeframes guide](kb/shipping) helpful.
#
# If you continue to experience issues or need further assistance, please do not hesitate to reach out. We are here to ensure your satisfaction.
#
# Thank you for your patience.
#
# Best regards,
# [Your Name]
# Customer Service Team
#
# ---
#
# This response is personalized, empathetic, and provides clear next steps, including links to relevant articles, to help Sarah with her query.**Subject:** Update on Your Order Status
#
# **Dear Sarah Johnson,**
#
# Thank you for reaching out to us regarding your order. We understand how important it is to receive your wireless headphones on time, especially since you have a premium account and have had a previous shipping delay.
#
# I have checked the status of your order (ORD-98765) and it is currently in transit with the tracking number 1Z999AA10123456784. Although it was estimated to arrive by December 20th, it seems there may be a delay.
#
# For more information on our shipping timeframes and what to do if there are further delays, you might find the [shipping timeframes guide](kb/shipping) helpful.
#
# If you continue to experience issues or need further assistance, please do not hesitate to reach out. We are here to ensure your satisfaction.
#
# Thank you for your patience.
#
# Best regards,
# [Your Name]
# Customer Service Team
#
# ---
#
# This response is personalized, empathetic, and provides clear next steps, including links to relevant articles, to help Sarah with her query.

# %%
# Test Case 2: Frustrated customer
ticket2 = """
Subject: THIRD TIME contacting support!!!
From: angry.customer@email.com
Customer ID: CUST-67890

This is ridiculous! I've contacted support twice already about my account being charged 
twice for the same order. Nobody has fixed this yet and it's been a week! 
I want a refund immediately or I'm canceling my account and leaving a bad review.
"""

result = customer_service_pipeline(ticket2)
# Out:
# ============================================================
# STAGE 1: TICKET CLASSIFICATION
# ============================================================
# {
#   "category": "Billing",
#   "priority": "Urgent",
#   "sentiment": "Angry",
#   "entities": {
#     "customer_id": "CUST-67890"
#   },
#   "escalate": true,
#   "summary": "An angry customer demands a refund and threatens to leave a bad review due to being charged twice for the same order."
# }{
#   "category": "Billing",
#   "priority": "Urgent",
#   "sentiment": "Angry",
#   "entities": {
#     "customer_id": "CUST-67890"
#   },
#   "escalate": true,
#   "summary": "An angry customer demands a refund and threatens to leave a bad review due to being charged twice for the same order."
# }
#
#
# ============================================================
# STAGE 2: CONTEXT PROCESSING
# ============================================================
# <thinking>To gather all relevant context for this ticket, I need to use the provided customer ID to retrieve the customer's history. Given the urgency and escalation flag, it's important to quickly provide the customer with all necessary information and a clear path to resolution. Here is the plan:
#
# 1. Retrieve the customer's history using the customer ID.
# 2. Identify the order(s) in question and billing details.
# 3. Look for any related tickets or communications that may provide insight into the issue.
#
# Once I have all the necessary information, I can compile the context and identify potential solutions.</thinking>
# Tool #4: get_customer_history
# ## Customer Context
# - **Customer ID**: CUST-67890
# - **Account Status**: Premium
# - **Member Since**: 2023-05-15
# - **Total Orders**: 24
# - **Lifetime Value**: $3450
# - **Previous Tickets**:
#   - **2025-11-20**: Shipping delay (Resolved)
#   - **2025-09-10**: Product question (Resolved)
#
# ## Issue Context
# - **Category**: Billing
# - **Priority**: Urgent
# - **Sentiment**: Angry
# - **Escalate**: True
# - **Summary**: An angry customer demands a refund and threatens to leave a bad review due to being charged twice for the same order.
#
# ## Relevant Solutions
# - The context does not provide specific details on the order(s) in question or any related billing details. However, given the urgency and escalation flag, I will need to look into the specific order(s) and billing information directly from the billing system or relevant logs.
#
# ## Special Notes
# - The customer has a premium account status, indicating a higher level of engagement and possibly higher expectations.
# - The customer has contacted support twice already and is very upset, making this a high-priority matter that requires immediate attention.
# - The customer is threatening to cancel their account and leave a bad review, which indicates a need for urgent resolution to maintain customer satisfaction and account retention.
#
# Given the urgency and the escalation flag, it's crucial to quickly identify the specific order(s) in question and the billing details to provide a clear path to resolution. I will proceed to gather more detailed billing information and then offer a solution to the customer.## Customer Context
# - **Customer ID**: CUST-67890
# - **Account Status**: Premium
# - **Member Since**: 2023-05-15
# - **Total Orders**: 24
# - **Lifetime Value**: $3450
# - **Previous Tickets**:
#   - **2025-11-20**: Shipping delay (Resolved)
#   - **2025-09-10**: Product question (Resolved)
#
# ## Issue Context
# - **Category**: Billing
# - **Priority**: Urgent
# - **Sentiment**: Angry
# - **Escalate**: True
# - **Summary**: An angry customer demands a refund and threatens to leave a bad review due to being charged twice for the same order.
#
# ## Relevant Solutions
# - The context does not provide specific details on the order(s) in question or any related billing details. However, given the urgency and escalation flag, I will need to look into the specific order(s) and billing information directly from the billing system or relevant logs.
#
# ## Special Notes
# - The customer has a premium account status, indicating a higher level of engagement and possibly higher expectations.
# - The customer has contacted support twice already and is very upset, making this a high-priority matter that requires immediate attention.
# - The customer is threatening to cancel their account and leave a bad review, which indicates a need for urgent resolution to maintain customer satisfaction and account retention.
#
# Given the urgency and the escalation flag, it's crucial to quickly identify the specific order(s) in question and the billing details to provide a clear path to resolution. I will proceed to gather more detailed billing information and then offer a solution to the customer.
#
#
# ============================================================
# STAGE 3: RESPONSE GENERATION
# ============================================================
# **Subject:** Immediate Action Required on Your Billing Issue
#
# **Dear [Customer's First Name],**
#
# I'm truly sorry to hear about the frustration you've experienced, and I sincerely apologize for the inconvenience. Your satisfaction is our top priority, and it's unacceptable that you've been charged twice for the same order. I completely understand your frustration, especially given this is your third contact with our support team.
#
# To address this issue promptly, I will escalate your case to our senior billing department for an immediate review. We value your business and your patience, and we're committed to resolving this matter swiftly.
#
# In the meantime, please allow me to provide you with a temporary refund for one of the charges as a goodwill gesture. Once the investigation is complete, we will ensure the remaining charge is fully refunded.
#
# I will personally follow up with you within 24 hours to provide you with a detailed update on our findings and the steps we will take to correct this issue. If you prefer, you can also reach out directly to our billing team at [billing-support@email.com](mailto:billing-support@email.com) for real-time updates.
#
# Rest assured, we are taking every possible step to prevent such issues from happening again and to make sure your experience with us moving forward is impeccable.
#
# Thank you for your understanding and patience.
#
# Best regards,
# [Your Name]
# Customer Service Team
#
# ---
#
# This response is designed to acknowledge the customer's frustration empathetically, provide an immediate partial solution, and assure them of further investigation and resolution. The inclusion of direct contact information for the billing team and a promise for a follow-up aims to reassure the customer and demonstrate our commitment to resolving their issue.**Subject:** Immediate Action Required on Your Billing Issue
#
# **Dear [Customer's First Name],**
#
# I'm truly sorry to hear about the frustration you've experienced, and I sincerely apologize for the inconvenience. Your satisfaction is our top priority, and it's unacceptable that you've been charged twice for the same order. I completely understand your frustration, especially given this is your third contact with our support team.
#
# To address this issue promptly, I will escalate your case to our senior billing department for an immediate review. We value your business and your patience, and we're committed to resolving this matter swiftly.
#
# In the meantime, please allow me to provide you with a temporary refund for one of the charges as a goodwill gesture. Once the investigation is complete, we will ensure the remaining charge is fully refunded.
#
# I will personally follow up with you within 24 hours to provide you with a detailed update on our findings and the steps we will take to correct this issue. If you prefer, you can also reach out directly to our billing team at [billing-support@email.com](mailto:billing-support@email.com) for real-time updates.
#
# Rest assured, we are taking every possible step to prevent such issues from happening again and to make sure your experience with us moving forward is impeccable.
#
# Thank you for your understanding and patience.
#
# Best regards,
# [Your Name]
# Customer Service Team
#
# ---
#
# This response is designed to acknowledge the customer's frustration empathetically, provide an immediate partial solution, and assure them of further investigation and resolution. The inclusion of direct contact information for the billing team and a promise for a follow-up aims to reassure the customer and demonstrate our commitment to resolving their issue.

# %%
# Test Case 3: Product question
ticket3 = """
Subject: Question about product compatibility
From: tech.user@email.com
Customer ID: CUST-11111

Hello! I'm interested in purchasing the USB-C cable but I want to make sure 
it's compatible with my MacBook Pro 2024. Can you confirm this works with 
the latest models? Also, does it support fast charging?

Thanks!
"""

result = customer_service_pipeline(ticket3)
# Out:
# ============================================================
# STAGE 1: TICKET CLASSIFICATION
# ============================================================
# {
#   "category": "Product",
#   "priority": "Low",
#   "sentiment": "Positive",
#   "entities": {
#     "customer_id": "CUST-11111",
#     "product_name": "USB-C cable"
#   },
#   "escalate": false,
#   "summary": "A customer is inquiring about the compatibility and fast charging support of a USB-C cable with their MacBook Pro 2024."
# }{
#   "category": "Product",
#   "priority": "Low",
#   "sentiment": "Positive",
#   "entities": {
#     "customer_id": "CUST-11111",
#     "product_name": "USB-C cable"
#   },
#   "escalate": false,
#   "summary": "A customer is inquiring about the compatibility and fast charging support of a USB-C cable with their MacBook Pro 2024."
# }
#
#
# ============================================================
# STAGE 2: CONTEXT PROCESSING
# ============================================================
# ## Customer Context
# - **Customer ID**: CUST-11111
# - **Account Status**: Not specified in the context
# - **Member Since**: Not provided
# - **Total Orders**: Not provided
# - **Lifetime Value**: Not provided
# - **Previous Tickets**: Not provided
#
# ## Issue Context
# - **Category**: Product
# - **Priority**: Low
# - **Sentiment**: Positive
# - **Escalate**: False
# - **Summary**: A customer is inquiring about the compatibility and fast charging support of a USB-C cable with their MacBook Pro 2024.
#
# ## Relevant Solutions
# - **"Product Compatibility Guide"** (URL: kb/product-compatibility)
# - **"USB-C Cable Specifications"** (URL: kb/usb-c-cable-specs)
#
# ## Special Notes
# - The customer has a positive sentiment and is seeking information to make an informed purchase decision.
# - The inquiry is specific to product compatibility and fast charging support, which are important factors for potential buyers.
#
# Based on the gathered information, it seems that the customer is looking for detailed information about the USB-C cable's compatibility with a MacBook Pro 2024 and whether it supports fast charging. I will provide the customer with the relevant knowledge base articles and any additional information that can help them make an informed decision. Since the priority is low and there is no escalation needed, this can be resolved with a direct response to the customer's inquiry.## Customer Context
# - **Customer ID**: CUST-11111
# - **Account Status**: Not specified in the context
# - **Member Since**: Not provided
# - **Total Orders**: Not provided
# - **Lifetime Value**: Not provided
# - **Previous Tickets**: Not provided
#
# ## Issue Context
# - **Category**: Product
# - **Priority**: Low
# - **Sentiment**: Positive
# - **Escalate**: False
# - **Summary**: A customer is inquiring about the compatibility and fast charging support of a USB-C cable with their MacBook Pro 2024.
#
# ## Relevant Solutions
# - **"Product Compatibility Guide"** (URL: kb/product-compatibility)
# - **"USB-C Cable Specifications"** (URL: kb/usb-c-cable-specs)
#
# ## Special Notes
# - The customer has a positive sentiment and is seeking information to make an informed purchase decision.
# - The inquiry is specific to product compatibility and fast charging support, which are important factors for potential buyers.
#
# Based on the gathered information, it seems that the customer is looking for detailed information about the USB-C cable's compatibility with a MacBook Pro 2024 and whether it supports fast charging. I will provide the customer with the relevant knowledge base articles and any additional information that can help them make an informed decision. Since the priority is low and there is no escalation needed, this can be resolved with a direct response to the customer's inquiry.
#
#
# ============================================================
# STAGE 3: RESPONSE GENERATION
# ============================================================
# **Subject:** Confirming Compatibility and Fast Charging Support for Your USB-C Cable
#
# **Dear Tech User,**
#
# Thank you for reaching out with your inquiry about our USB-C cable. We're pleased to hear about your interest and are here to help ensure you make an informed purchase decision.
#
# **Compatibility:**
# The USB-C cable we offer is designed to be fully compatible with the latest models of MacBook Pro, including your MacBook Pro 2024. Our product is engineered to meet the high standards of Apple's latest technology, ensuring seamless connectivity and performance.
#
# **Fast Charging Support:**
# Regarding fast charging, our USB-C cable is equipped with high-speed data transfer capabilities, which allows it to support fast charging when connected to a compatible power source. This means you can expect efficient charging speeds, helping to keep your device powered up and ready to go.
#
# For more detailed information on our product compatibility and specifications, you might find our [Product Compatibility Guide](kb/product-compatibility) and [USB-C Cable Specifications](kb/usb-c-cable-specs) particularly useful.
#
# If you have any further questions or need additional assistance, please do not hesitate to reach out. We're here to support you every step of the way.
#
# Best regards,
# [Your Name]
# Customer Service Team
#
# ---
#
# This response aims to address the customer's specific questions about product compatibility and fast charging support in a clear and informative manner. It also provides links to relevant knowledge base articles for additional information, ensuring the customer has all the details they need to confidently proceed with their purchase.**Subject:** Confirming Compatibility and Fast Charging Support for Your USB-C Cable
#
# **Dear Tech User,**
#
# Thank you for reaching out with your inquiry about our USB-C cable. We're pleased to hear about your interest and are here to help ensure you make an informed purchase decision.
#
# **Compatibility:**
# The USB-C cable we offer is designed to be fully compatible with the latest models of MacBook Pro, including your MacBook Pro 2024. Our product is engineered to meet the high standards of Apple's latest technology, ensuring seamless connectivity and performance.
#
# **Fast Charging Support:**
# Regarding fast charging, our USB-C cable is equipped with high-speed data transfer capabilities, which allows it to support fast charging when connected to a compatible power source. This means you can expect efficient charging speeds, helping to keep your device powered up and ready to go.
#
# For more detailed information on our product compatibility and specifications, you might find our [Product Compatibility Guide](kb/product-compatibility) and [USB-C Cable Specifications](kb/usb-c-cable-specs) particularly useful.
#
# If you have any further questions or need additional assistance, please do not hesitate to reach out. We're here to support you every step of the way.
#
# Best regards,
# [Your Name]
# Customer Service Team
#
# ---
#
# This response aims to address the customer's specific questions about product compatibility and fast charging support in a clear and informative manner. It also provides links to relevant knowledge base articles for additional information, ensuring the customer has all the details they need to confidently proceed with their purchase.

# %% [markdown]
# ## Step 6: Inspect Pipeline Stages

# %%
# Access individual stage outputs
print("=== CLASSIFICATION ===")
print(result['classification'][:300] + "...\n")

print("=== CONTEXT ===")
print(result['context'][:300] + "...\n")

print("=== RESPONSE ===")
print(result['response'])
# Out:
# === CLASSIFICATION ===
# {
#   "category": "Product",
#   "priority": "Low",
#   "sentiment": "Positive",
#   "entities": {
#     "customer_id": "CUST-11111",
#     "product_name": "USB-C cable"
#   },
#   "escalate": false,
#   "summary": "A customer is inquiring about the compatibility and fast charging support of a USB-C cable with their ...
#
# === CONTEXT ===
# ## Customer Context
# - **Customer ID**: CUST-11111
# - **Account Status**: Not specified in the context
# - **Member Since**: Not provided
# - **Total Orders**: Not provided
# - **Lifetime Value**: Not provided
# - **Previous Tickets**: Not provided
#
# ## Issue Context
# - **Category**: Product
# - **Priority**: Low...
#
# === RESPONSE ===
# **Subject:** Confirming Compatibility and Fast Charging Support for Your USB-C Cable
#
# **Dear Tech User,**
#
# Thank you for reaching out with your inquiry about our USB-C cable. We're pleased to hear about your interest and are here to help ensure you make an informed purchase decision.
#
# **Compatibility:**
# The USB-C cable we offer is designed to be fully compatible with the latest models of MacBook Pro, including your MacBook Pro 2024. Our product is engineered to meet the high standards of Apple's latest technology, ensuring seamless connectivity and performance.
#
# **Fast Charging Support:**
# Regarding fast charging, our USB-C cable is equipped with high-speed data transfer capabilities, which allows it to support fast charging when connected to a compatible power source. This means you can expect efficient charging speeds, helping to keep your device powered up and ready to go.
#
# For more detailed information on our product compatibility and specifications, you might find our [Product Compatibility Guide](kb/product-compatibility) and [USB-C Cable Specifications](kb/usb-c-cable-specs) particularly useful.
#
# If you have any further questions or need additional assistance, please do not hesitate to reach out. We're here to support you every step of the way.
#
# Best regards,
# [Your Name]
# Customer Service Team
#
# ---
#
# This response aims to address the customer's specific questions about product compatibility and fast charging support in a clear and informative manner. It also provides links to relevant knowledge base articles for additional information, ensuring the customer has all the details they need to confidently proceed with their purchase.

# %% [markdown]
# ## Exercise Variations
#
# Try modifying the pipeline:
#
# 1. **Add Sentiment Analysis Agent** for deeper emotion detection
# 2. **Add Auto-Resolution Agent** for simple tickets
# 3. **Add Quality Check Agent** to review responses before sending
# 4. **Implement routing logic** based on classification (escalate urgent tickets)
# 5. **Add feedback loop** to learn from customer satisfaction ratings

# %% [markdown]
# ## Key Learnings
#
# ✅ **Sequential Flow**: Classify → Process → Respond
# ✅ **Tool Integration**: Process agent uses multiple context tools
# ✅ **Context Passing**: Full ticket context flows through pipeline
# ✅ **Personalization**: Response adapts to sentiment and customer history
# ✅ **Structured Classification**: JSON output enables routing logic
