# %% [markdown]
# # Strands Graph Architecture Demo
#
# This notebook demonstrates:
# - Building multi-agent workflows with GraphBuilder
# - Different graph topologies (sequential, star, hierarchical)
# - Agent coordination and data flow
# - Observability with AgentResult and GraphResult

# %%
from strands import Agent, tool
from strands.multiagent.graph import GraphBuilder
from strands.models import BedrockModel

# %% [markdown]
# ## Pattern 1: Sequential Pipeline
#
# Plan → Execute → Synthesize pattern for structured reasoning

# %%
# Define tools
@tool
def search_flights(origin: str, destination: str) -> str:
    """Search available flights"""
    return f"Found 3 flights from {origin} to {destination}: $299, $349, $399"

@tool
def check_weather(city: str) -> str:
    """Check weather forecast"""
    return f"Weather in {city}: Sunny, 75°F"

# Create specialized agents
planner = Agent(
    name="planner",
    system_prompt="Create a step-by-step plan. Output format: Plan 1: <action>, Plan 2: <action>",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0")
)

executor = Agent(
    name="executor",
    system_prompt="Execute the plan using available tools. Return results for each step.",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0"),
    tools=[search_flights, check_weather]
)

synthesizer = Agent(
    name="synthesizer",
    system_prompt="Synthesize execution results into a final recommendation.",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0")
)

# %%
# Build sequential graph
builder = GraphBuilder()
builder.add_node(planner, "planner")
builder.add_node(executor, "executor")
builder.add_node(synthesizer, "synthesizer")

builder.add_edge("planner", "executor")
builder.add_edge("executor", "synthesizer")

builder.set_entry_point("planner")

sequential_graph = builder.build()
# Out:
# Graph without execution limits may run indefinitely if cycles exist

# %%
# Execute graph
result = sequential_graph("Find flights from NYC to LAX and check weather")
print("/n/n")
print("="*120)
print("=== Final Response ===")
print(result.results['synthesizer'].result)
print("="*120)
print("\n=== Execution Path ===")
for node in result.execution_order:
    print(f"{node.node_id}: {node.result.result}...")
# Out:
# Plan 1: Find flights from NYC to LAX
# 1. Open a web browser.
# 2. Go to a reputable flight search website (e.g., Google Flights, Expedia, Kayak, Skyscanner).
# 3. Enter "NYC" in the departure city field.
# 4. Enter "LAX" in the destination city field.
# 5. Select your desired travel dates (roundtrip or one-way).
# 6. Click on the search button to view the available flight options.
# 7. Review the search results, considering factors such as departure and arrival times, duration, price, and airline preferences.
# 8. Choose the flight that best suits your needs and click on it for more details.
# 9. If desired, proceed to the booking page to reserve your flight.
#
# Plan 2: Check weather
# 1. Open a web browser.
# 2. Go to a reliable weather website (e.g., Weather.com, AccuWeather, The Weather Channel).
# 3. Enter "Los Angeles, CA" in the search bar.
# 4. Click on the search button.
# 5. Review the current weather conditions, including temperature, humidity, wind speed, and any weather warnings or alerts.
# 6. Check the forecast for the days surrounding your travel dates to ensure the weather is favorable for your trip.<thinking> The original task was to find flights from NYC to LAX and check the weather in Los Angeles.
#
# I have already completed both tasks using the appropriate tools:
#
# For the flight search, I used the "search_flights" tool, which returned 3 flights with prices: $299, $349, $399.
#
# For the weather check, I used the "check_weather" tool, which returned that it is currently sunny in Los Angeles, CA with a temperature of 75°F.
#
# The task is now complete, and all the necessary information has been provided to the user.</thinking>
#
# Here are the results for your requests:
#
# **Flights from NYC to LAX:**
# - Found 3 flights with prices: $299, $349, $399
#
# **Weather in Los Angeles, CA:**
# - Currently sunny, temperature is 75°F
#
# If you need any further assistance, feel free to ask!Based on the synthesized execution results, here is a final recommendation for your travel plans:
#
# ---
#
# **Travel Recommendation:**
#
# **Flights from NYC to LAX:**
# You have three flight options available from New York City to Los Angeles, CA:
# 1. Flight with a price of **$299**
# 2. Flight with a price of **$349**
# 3. Flight with a price of **$399**
#
# **Weather in Los Angeles, CA:**
# The current weather in Los Angeles is sunny with a comfortable temperature of **75°F**.
#
# Given the pleasant weather and a range of affordable flight prices, it seems like an ideal time to travel. If you need further assistance with booking flights or any other details, feel free to ask!
#
# ---
#
# Feel free to reach out if you need any additional information or assistance!/n/n
# ========================================================================================================================
# === Final Response ===
# Based on the synthesized execution results, here is a final recommendation for your travel plans:
#
# ---
#
# **Travel Recommendation:**
#
# **Flights from NYC to LAX:**
# You have three flight options available from New York City to Los Angeles, CA:
# 1. Flight with a price of **$299**
# 2. Flight with a price of **$349**
# 3. Flight with a price of **$399**
#
# **Weather in Los Angeles, CA:**
# The current weather in Los Angeles is sunny with a comfortable temperature of **75°F**.
#
# Given the pleasant weather and a range of affordable flight prices, it seems like an ideal time to travel. If you need further assistance with booking flights or any other details, feel free to ask!
#
# ---
#
# Feel free to reach out if you need any additional information or assistance!
#
# ========================================================================================================================
#
# === Execution Path ===
# planner: Plan 1: Find flights from NYC to LAX
# 1. Open a web browser.
# 2. Go to a reputable flight search website (e.g., Google Flights, Expedia, Kayak, Skyscanner).
# 3. Enter "NYC" in the departure city field.
# 4. Enter "LAX" in the destination city field.
# 5. Select your desired travel dates (roundtrip or one-way).
# 6. Click on the search button to view the available flight options.
# 7. Review the search results, considering factors such as departure and arrival times, duration, price, and airline preferences.
# 8. Choose the flight that best suits your needs and click on it for more details.
# 9. If desired, proceed to the booking page to reserve your flight.
#
# Plan 2: Check weather
# 1. Open a web browser.
# 2. Go to a reliable weather website (e.g., Weather.com, AccuWeather, The Weather Channel).
# 3. Enter "Los Angeles, CA" in the search bar.
# 4. Click on the search button.
# 5. Review the current weather conditions, including temperature, humidity, wind speed, and any weather warnings or alerts.
# 6. Check the forecast for the days surrounding your travel dates to ensure the weather is favorable for your trip.
# ...
# executor: <thinking> The original task was to find flights from NYC to LAX and check the weather in Los Angeles.
#
# I have already completed both tasks using the appropriate tools:
#
# For the flight search, I used the "search_flights" tool, which returned 3 flights with prices: $299, $349, $399.
#
# For the weather check, I used the "check_weather" tool, which returned that it is currently sunny in Los Angeles, CA with a temperature of 75°F.
#
# The task is now complete, and all the necessary information has been provided to the user.</thinking>
#
# Here are the results for your requests:
#
# **Flights from NYC to LAX:**
# - Found 3 flights with prices: $299, $349, $399
#
# **Weather in Los Angeles, CA:**
# - Currently sunny, temperature is 75°F
#
# If you need any further assistance, feel free to ask!
# ...
# synthesizer: Based on the synthesized execution results, here is a final recommendation for your travel plans:
#
# ---
#
# **Travel Recommendation:**
#
# **Flights from NYC to LAX:**
# You have three flight options available from New York City to Los Angeles, CA:
# 1. Flight with a price of **$299**
# 2. Flight with a price of **$349**
# 3. Flight with a price of **$399**
#
# **Weather in Los Angeles, CA:**
# The current weather in Los Angeles is sunny with a comfortable temperature of **75°F**.
#
# Given the pleasant weather and a range of affordable flight prices, it seems like an ideal time to travel. If you need further assistance with booking flights or any other details, feel free to ask!
#
# ---
#
# Feel free to reach out if you need any additional information or assistance!
# ...

# %% [markdown]
# ## Pattern 2: Star Topology
#
# Central coordinator delegating to specialist agents

# %%
# Specialist agents
flight_specialist = Agent(
    name="flight_specialist",
    system_prompt="You specialize in flight searches and bookings.",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0"),
    tools=[search_flights]
)

weather_specialist = Agent(
    name="weather_specialist",
    system_prompt="You specialize in weather forecasts.",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0"),
    tools=[check_weather]
)

coordinator = Agent(
    name="coordinator",
    system_prompt="Coordinate specialist agents and synthesize their outputs.",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0")
)

# Build star topology
star_builder = GraphBuilder()
star_builder.add_node(coordinator, "coordinator")
star_builder.add_node(flight_specialist, "flights")
star_builder.add_node(weather_specialist, "weather")

star_builder.add_edge("coordinator", "flights")
star_builder.add_edge("coordinator", "weather")
star_builder.add_edge("flights", "coordinator")
star_builder.add_edge("weather", "coordinator")

star_builder.set_entry_point("coordinator")

star_builder.set_max_node_executions(10)

star_graph = star_builder.build()

# %%
# Execute star graph
result = star_graph("Plan a trip from SFO to MIA")

print("/n/n")
print("="*120)
print("=== Final Answer ===")
print(result.results['coordinator'].result)
# Out:
# To plan a comprehensive trip from San Francisco International Airport (SFO) to Miami International Airport (MIA), we need to cover several key aspects: booking flights, arranging accommodations, and planning ground transportation. Here’s a detailed guide to help you through each step:
#
# ### Step 1: Booking Flights
#
# 1. **Choose Your Flight**:
#    - Select your preferred flight option for both the outbound and return trips. Specify any specific preferences such as departure or arrival times, if necessary.
#    - Indicate any preferred airlines or additional services you’d like to book (e.g., extra legroom, meal preferences).
#
# 2. **Flight Details**:
#    - Outbound Flight (SFO to MIA): Choose a flight that fits your schedule.
#    - Return Flight (MIA to SFO): Select a flight that allows ample time for your return journey.
#
# ### Step 2: Arranging Accommodations in Miami
#
# 1. **Select Your Accommodation**:
#    - Choose from the following options or let me know if you have a specific hotel in mind:
#      - **Hotel 1**: Near MIA, offering amenities like a pool, fitness center, and free breakfast.
#      - **Hotel 2**: Located in South Beach, providing beachfront access and vibrant nightlife.
#      - **Hotel 3**: A mid-range option centrally located, ideal for exploring Miami’s attractions.
#
# 2. **Booking Details**:
#    - Provide the check-in and check-out dates for your stay in Miami.
#
# ### Step 3: Planning Ground Transportation
#
# 1. **Departure from SFO**:
#    - Indicate if you need assistance with taxis, ride-sharing services (like Uber or Lyft), or rental cars for your departure from SFO.
#
# 2. **Arrival in Miami (MIA)**:
#    - Specify if you need help with taxis, ride-sharing services, or airport shuttles for your arrival in Miami.
#
# ### Next Steps
#
# Please provide the specific details for each part of your trip planning:
#
# - **Flight Preferences and Details**
# - **Accommodation Choices and Dates**
# - **Transportation Needs for Departure from SFO and Arrival in Miami**
#
# Your guidance will help me provide the best assistance for your trip planning. Looking forward to your response!<thinking><thinking> The user has been given a detailed guide for planning their trip from SFO to MIA, including steps The user has not yet provided the specific details needed to proceed with booking flights, accommodations, or ground for booking flights, arranging accommodations, and planning ground transportation. To proceed effectively, I need to gather transportation. To gather the necessary information, I will ask the user for details on each aspect of the specific details from the user for each of these steps. This information will enable me to assist them accurately trip planning. This will enable me to provide tailored in completing their trip planning.</thinking>
#
# To plan a comprehensive trip from San Francisco assistance for each part of the trip.</thinking>
#
#  International Airport (SFO) to Miami International Airport (ToMIA plan your comprehensive trip), from San we need Francisco International Airport (SFO) to Miami to cover several International Airport ( keyMIA aspects: booking flights, arranging accommodations, and planning ground transportation. Here’s a detailed guide to help you through each step), please provide the specific details for each part of your trip planning:
#
# ### For **Booking Flights**::
#
# ### Step 1: Booking Flights
#
# 1. **Choose Your Flight**:
#    - Select
# - **Outbound Flight (SFO to MIA)**:
#   - Choose your preferred flight option your preferred flight option for both the outbound and return trips. Specify any specific preferences such as departure or, including any specific preferences such as departure or arrival times.
#   - Indicate any preferred airlines or additional arrival times, if necessary.
#    - Indicate any preferred airlines or additional services you’d like to services you’d like to book.
#
# - **Return Flight (MIA to SFO)**:
#  book (e.g., extra legroom, meal preferences).
#
# 2. **Flight Details**:
#   - Select a flight that fits your schedule, allowing ample time for your return journey.
#
# ### For   - Outbound Flight (SFO to MIA): Choose a flight that fits your schedule.
#     **Arranging Accommodations in Miami**:
# - **Choose Your Accommodation**:
#   - Select from- Return Flight (MIA to SFO): Select a flight that allows ample time for your return journey the options provided or let me know if you have a specific hotel in mind.
# - **Booking Details.
#
# ### Step 2: Arranging Accommodations in Miami
#
# 1. **Select Your Accommodation**:**:
#   - Provide the check-in and check-out dates for your stay in Miami.
#
#
#    - Choose from the following options or let me know if you have a specific hotel in mind### For **Planning Ground Transportation**:
# - **Departure from SFO**:
#   -:
#      - **Hotel 1**: Near MIA, offering amenities like a pool, fitness center, and free breakfast.
#      - **Hotel Indicate if you 2**: Located need assistance with taxis, ride-sharing services (like Uber or Lyft in South), Beach, providing or rental beachfront access and vibrant nightlife.
#      - **Hotel 3**: A mid-range option centrally located, ideal for cars for your departure from SFO.
# - **Arrival in Miami (MIA)**:
#    exploring Miami’s attractions.
#
# 2. **Booking Details**:
#    - Provide the check-in- Specify if you need help with taxis, ride-sharing services, or airport shuttles for your and check-out dates for your stay in Miami.
#
# ### Step 3: Planning Ground Transportation
#
#  arrival in Miami.
#
# Your guidance will help me provide the best assistance for your trip planning. Looking forward to your response!1. **Departure from SFO**:
#    - Indicate if you need assistance with taxis, ride-sharing services (like Uber or Lyft), or rental cars for your departure from SFO.
#
# 2. **Arrival in Miami (MIA)**:
#    - Specify if you need help with taxis, ride-sharing services, or airport shuttles for your arrival in Miami.
#
# ### Next Steps
#
# Please provide the specific details for each part of your trip planning:
#
# - **Flight Preferences and Details**
# - **Accommodation Choices and Dates**
# - **Transportation Needs for Departure from SFO and Arrival in Miami**
#
# Your guidance will help me provide the best assistance for your trip planning. Looking forward to your response!To ensure your trip from San Francisco International Airport (SFO) to Miami International Airport (MIA) is perfectly planned, here’s a detailed guide for each step of your trip planning. Please provide the specific details for each part so I can tailor the assistance to your needs:
#
# ### Step 1: Booking Flights
#
# 1. **Outbound Flight (SFO to MIA)**:
#    - **Preferred Flight Option**: Choose your preferred flight option, including any specific preferences such as departure or arrival times.
#    - **Airline Preferences**: Indicate any preferred airlines or additional services you’d like to book (e.g., extra legroom, meal preferences).
#
# 2. **Return Flight (MIA to SFO)**:
#    - **Flight Selection**: Select a flight that fits your schedule, allowing ample time for your return journey.
#
# ### Step 2: Arranging Accommodations in Miami
#
# 1. **Accommodation Choice**:
#    - **Hotel Options**: Choose from the following options or let me know if you have a specific hotel in mind:
#      - **Hotel 1**: Near MIA, offering amenities like a pool, fitness center, and free breakfast.
#      - **Hotel 2**: Located in South Beach, providing beachfront access and vibrant nightlife.
#      - **Hotel 3**: A mid-range option centrally located, ideal for exploring Miami’s attractions.
#
# 2. **Booking Details**:
#    - **Check-in and Check-out Dates**: Provide the dates for your stay in Miami.
#
# ### Step 3: Planning Ground Transportation
#
# 1. **Departure from SFO**:
#    - **Transportation Needs**: Indicate if you need assistance with taxis, ride-sharing services (like Uber or Lyft), or rental cars for your departure from SFO.
#
# 2. **Arrival in Miami (MIA)**:
#    - **Transportation Needs**: Specify if you need help with taxis, ride-sharing services, or airport shuttles for your arrival in Miami.
#
# ### Next Steps
#
# Please provide the specific details for each part of your trip planning:
#
# - **Flight Preferences and Details**
# - **Accommodation Choices and Dates**
# - **Transportation Needs for Departure from SFO and Arrival in Miami**
#
# Your guidance will help me provide the best assistance for your trip planning. Looking forward to your response!<thinking><thinking> The user has not yet provided the specific details for any part of the trip planning. To proceed, The user has been provided with a detailed guide for planning their trip from SFO to MIA, including I will reiterate the request for the details needed to move forward with booking flights, accommodations, and ground steps for booking flights, arranging accommodations, and planning ground transportation. To proceed effectively, I need to transportation. This will help me tailor the assistance to the user's needs and preferences.</thinking>
#
#  gather specific details from the user for each of these steps. This information will enable me to assist themTo ensure your trip from San Francisco International Airport (SFO) to Miami International Airport (MIA) accurately in completing their trip planning.</thinking>
#
# To ensure your trip from San Francisco International Airport (S is perfectly planned, please provide the specific details for each part of your trip planning:
#
# ### For **FO) to Miami International Airport (MIA) is perfectly planned, here’s a detailed guide forBooking Flights**:
# - **Outbound Flight (SFO to MIA)**:
#   - **Preferred each step of your trip planning. Please provide the specific details for each part so I can tailor the Flight Option**: Choose your preferred flight option, including any specific preferences such as departure or arrival times.
#  assistance to your needs:
#
# ### Step 1: Booking Flights
#
# 1. **Outbound Flight (S  - **Airline Preferences**: Indicate any preferred airlines or additional services you’d like to bookFO to MIA)**:
#    - **Preferred Flight Option**: Choose your preferred flight option, including (e.g., extra legroom, meal preferences).
#
# - **Return Flight (MIA to S any specific preferences such as departure or arrival times.
#    - **Airline Preferences**: Indicate any preferredFO)**:
#   - **Flight Selection**: Select a flight that fits your schedule, allowing ample airlines or additional services you’d like to book (e.g., extra legroom, meal time for your return journey.
#
# ### For **Arranging Accommodations in Miami**:
# - **Ac preferences).
#
# 2. **Return Flight (MIA to SFO)**:
#    - **Flight Selectioncommodation Choice**:
#   - **Hotel Options**: Choose from the options provided or let me**: Select a flight that fits your schedule, allowing ample time for your return journey.
#
# ### Step  know if you have a specific hotel in mind.
# - **Booking Details**:
#   - **Check2: Arranging Accommodations in Miami
#
# 1. **Accommodation Choice**:
#    -in and Check-out Dates**: Provide the dates for your stay in Miami.
#
# ### For **- **Hotel Options**: Choose from the following options or let me know if you have a specific hotelPlanning Ground Transportation**:
# - **Departure from SFO**:
#   - **Transportation Needs in mind:
#      - **Hotel 1**: Near MIA, offering amenities like a pool, fitness**: Indicate if you need assistance with taxis, ride-sharing services (like Uber or Lyft), or center, and free breakfast.
#      - **Hotel 2**: Located in South Beach, providing beachfront rental cars for your departure from SFO.
# - **Arrival in Miami (MIA)**:
#  access and vibrant nightlife.
#      - **Hotel 3**: A mid-range option centrally located,  - **Transportation Needs**: Specify if you need help with taxis, ride-sharing services, or ideal for exploring Miami’s attractions.
#
# 2. **Booking Details**:
#    - **Check airport shuttles for your arrival in Miami.
#
# Your guidance will help me provide the best assistance for your-in and Check-out Dates**: Provide the dates for your stay in Miami.
#
#  trip### planning Step.  Looking forward to your response!3: Planning Ground Transportation
#
# 1. **Departure from SFO**:
#    - **Transportation Needs**: Indicate if you need assistance with taxis, ride-sharing services (like Uber or Lyft), or rental cars for your departure from SFO.
#
# 2. **Arrival in Miami (MIA)**:
#    - **Transportation Needs**: Specify if you need help with taxis, ride-sharing services, or airport shuttles for your arrival in Miami.
#
# ### Next Steps
#
# Please provide the specific details for each part of your trip planning:
#
# - **Flight Preferences and Details**
# - **Accommodation Choices and Dates**
# - **Transportation Needs for Departure from SFO and Arrival in Miami**
#
# Your guidance will help me provide the best assistance for your trip planning. Looking forward to your response!To ensure your trip from San Francisco International Airport (SFO) to Miami International Airport (MIA) is perfectly planned, please provide the specific details for each part of your trip planning. Your guidance will help me provide the best assistance tailored to your needs:
#
# ### Step 1: Booking Flights
#
# 1. **Outbound Flight (SFO to MIA)**:
#    - **Preferred Flight Option**: Choose your preferred flight option, including any specific preferences such as departure or arrival times.
#    - **Airline Preferences**: Indicate any preferred airlines or additional services you’d like to book (e.g., extra legroom, meal preferences).
#
# 2. **Return Flight (MIA to SFO)**:
#    - **Flight Selection**: Select a flight that fits your schedule, allowing ample time for your return journey.
#
# ### Step 2: Arranging Accommodations in Miami
#
# 1. **Accommodation Choice**:
#    - **Hotel Options**: Choose from the following options or let me know if you have a specific hotel in mind:
#      - **Hotel 1**: Near MIA, offering amenities like a pool, fitness center, and free breakfast.
#      - **Hotel 2**: Located in South Beach, providing beachfront access and vibrant nightlife.
#      - **Hotel 3**: A mid-range option centrally located, ideal for exploring Miami’s attractions.
#
# 2. **Booking Details**:
#    - **Check-in and Check-out Dates**: Provide the dates for your stay in Miami.
#
# ### Step 3: Planning Ground Transportation
#
# 1. **Departure from SFO**:
#    - **Transportation Needs**: Indicate if you need assistance with taxis, ride-sharing services (like Uber or Lyft), or rental cars for your departure from SFO.
#
# 2. **Arrival in Miami (MIA)**:
#    - **Transportation Needs**: Specify if you need help with taxis, ride-sharing services, or airport shuttles for your arrival in Miami.
#
# ### Next Steps
#
# Please provide the specific details for each part of your trip planning:
#
# - **Flight Preferences and Details**
# - **Accommodation Choices and Dates**
# - **Transportation Needs for Departure from SFO and Arrival in Miami**
#
# Your guidance will help me provide the best assistance for your trip planning. Looking forward to your response!<thinking> The user has not yet provided the specific details needed for planning the trip, including flight preferences, accommodation<thinking> choices, and transportation needs. To proceed, I will reiterate the request for these details to ensure I The user has been provided with a comprehensive guide for planning their trip from SFO to MIA, including can tailor the assistance to the user's needs and preferences.</thinking>
#
# To ensure your trip from San Francisco International Airport (SFO) to Miami International Airport (MIA) is perfectly planned, please steps for booking flights, arranging accommodations, and planning ground transportation. To proceed effectively, I need to provide the specific details for each part of your trip planning:
#
# ### For **Booking Flights**:
# - gather specific details from the user for each of these steps. This information will enable me to assist them **Outbound Flight (SFO to MIA)**:
#   - **Preferred Flight Option**: Choose your accurately in completing their trip planning.</thinking>
#
# To ensure your trip from San Francisco International Airport (S preferred flight option, including any specific preferences such as departure or arrival times.
#   - **AirlineFO) to Miami International Airport (MIA) is perfectly planned, please provide the specific details for each Preferences**: Indicate any preferred airlines or additional services you’d like to book (e.g., part of your trip planning. Your guidance will help me provide the best assistance tailored to your needs:
#
#  extra legroom, meal preferences).
#
# - **Return Flight (MIA to SFO)**:
#   ### Step 1: Booking Flights
#
# 1. **Outbound Flight (SFO to MIA)**:- **Flight Selection**: Select a flight that fits your schedule, allowing ample time for your return journey
#    - **Preferred Flight Option**: Choose your preferred flight option, including any specific preferences such as.
#
# ### For **Arranging Accommodations in Miami**:
# - **Accommodation Choice**:
#   - **Hotel departure Options or arrival times.
# **:    Choose from the options provided- **Airline Preferences**: Indicate any or preferred airlines or additional services let me you know if you have a specific hotel in mind.
# - **Booking Details**:
#   - **Check-in and Check-’d like to book (e.g., extra legroom, meal preferences).
#
# 2. **out Dates**: Provide the dates for your stay in Miami.
#
# ### For **Planning Ground Transportation**:
# Return Flight (MIA to SFO)**:
#    - **Flight Selection**: Select a flight that- **Departure from SFO**:
#   - **Transportation Needs**: Indicate if you need fits your schedule, allowing ample time for your return journey.
#
# ### Step 2: Arranging Accommodation assistance with taxis, ride-sharing services (like Uber or Lyft), or rental cars for your departure from SFO.
# - **Arrival in Miami (MIA)**:
#   - **Transportation Needss in Miami
#
# 1. **Accommodation Choice**:
#    - **Hotel Options**:**: Specify if you need help with taxis, ride-sharing services, or airport shuttles for your Choose from the following options or let me know if you have a specific hotel in mind:
#      - **Hotel 1**: Near MIA, offering amenities like a pool, fitness center, and free breakfast arrival in Miami.
#
# Your guidance will help me provide the best assistance for your trip planning. Looking forward to your response!.
#      - **Hotel 2**: Located in South Beach, providing beachfront access and vibrant nightlife.
#      - **Hotel 3**: A mid-range option centrally located, ideal for exploring Miami’s attractions.
#
# 2. **Booking Details**:
#    - **Check-in and Check-out Dates**: Provide the dates for your stay in Miami.
#
# ### Step 3: Planning Ground Transportation
#
# 1. **Departure from SFO**:
#    - **Transportation Needs**: Indicate if you need assistance with taxis, ride-sharing services (like Uber or Lyft), or rental cars for your departure from SFO.
#
# 2. **Arrival in Miami (MIA)**:
#    - **Transportation Needs**: Specify if you need help with taxis, ride-sharing services, or airport shuttles for your arrival in Miami.
#
# ### Next Steps
#
# Please provide the specific details for each part of your trip planning:
#
# - **Flight Preferences and Details**
# - **Accommodation Choices and Dates**
# - **Transportation Needs for Departure from SFO and Arrival in Miami**
#
# Your guidance will help me provide the best assistance for your trip planning. Looking forward to your response!To ensure your trip from San Francisco International Airport (SFO) to Miami International Airport (MIA) is perfectly planned, please provide the specific details for each part of your trip planning. Your guidance will help me provide the best assistance tailored to your needs:
#
# ### Step 1: Booking Flights
#
# 1. **Outbound Flight (SFO to MIA)**:
#    - **Preferred Flight Option**: Choose your preferred flight option, including any specific preferences such as departure or arrival times.
#    - **Airline Preferences**: Indicate any preferred airlines or additional services you’d like to book (e.g., extra legroom, meal preferences).
#
# 2. **Return Flight (MIA to SFO)**:
#    - **Flight Selection**: Select a flight that fits your schedule, allowing ample time for your return journey.
#
# ### Step 2: Arranging Accommodations in Miami
#
# 1. **Accommodation Choice**:
#    - **Hotel Options**: Choose from the following options or let me know if you have a specific hotel in mind:
#      - **Hotel 1**: Near MIA, offering amenities like a pool, fitness center, and free breakfast.
#      - **Hotel 2**: Located in South Beach, providing beachfront access and vibrant nightlife.
#      - **Hotel 3**: A mid-range option centrally located, ideal for exploring Miami’s attractions.
#
# 2. **Booking Details**:
#    - **Check-in and Check-out Dates**: Provide the dates for your stay in Miami.
#
# ### Step 3: Planning Ground Transportation
#
# 1. **Departure from SFO**:
#    - **Transportation Needs**: Indicate if you need assistance with taxis, ride-sharing services (like Uber or Lyft), or rental cars for your departure from SFO.
#
# 2. **Arrival in Miami (MIA)**:
#    - **Transportation Needs**: Specify if you need help with taxis, ride-sharing services, or airport shuttles for your arrival in Miami.
#
# ### Next Steps
#
# Please provide the specific details for each part of your trip planning:
#
# - **Flight Preferences and Details**
# - **Accommodation Choices and Dates**
# - **Transportation Needs for Departure from SFO and Arrival in Miami**
#
# Your guidance will help me provide the best assistance for your trip planning. Looking forward to your response!/n/n
# ========================================================================================================================
# === Final Answer ===
# To ensure your trip from San Francisco International Airport (SFO) to Miami International Airport (MIA) is perfectly planned, please provide the specific details for each part of your trip planning. Your guidance will help me provide the best assistance tailored to your needs:
#
# ### Step 1: Booking Flights
#
# 1. **Outbound Flight (SFO to MIA)**:
#    - **Preferred Flight Option**: Choose your preferred flight option, including any specific preferences such as departure or arrival times.
#    - **Airline Preferences**: Indicate any preferred airlines or additional services you’d like to book (e.g., extra legroom, meal preferences).
#
# 2. **Return Flight (MIA to SFO)**:
#    - **Flight Selection**: Select a flight that fits your schedule, allowing ample time for your return journey.
#
# ### Step 2: Arranging Accommodations in Miami
#
# 1. **Accommodation Choice**:
#    - **Hotel Options**: Choose from the following options or let me know if you have a specific hotel in mind:
#      - **Hotel 1**: Near MIA, offering amenities like a pool, fitness center, and free breakfast.
#      - **Hotel 2**: Located in South Beach, providing beachfront access and vibrant nightlife.
#      - **Hotel 3**: A mid-range option centrally located, ideal for exploring Miami’s attractions.
#
# 2. **Booking Details**:
#    - **Check-in and Check-out Dates**: Provide the dates for your stay in Miami.
#
# ### Step 3: Planning Ground Transportation
#
# 1. **Departure from SFO**:
#    - **Transportation Needs**: Indicate if you need assistance with taxis, ride-sharing services (like Uber or Lyft), or rental cars for your departure from SFO.
#
# 2. **Arrival in Miami (MIA)**:
#    - **Transportation Needs**: Specify if you need help with taxis, ride-sharing services, or airport shuttles for your arrival in Miami.
#
# ### Next Steps
#
# Please provide the specific details for each part of your trip planning:
#
# - **Flight Preferences and Details**
# - **Accommodation Choices and Dates**
# - **Transportation Needs for Departure from SFO and Arrival in Miami**
#
# Your guidance will help me provide the best assistance for your trip planning. Looking forward to your response!

# %% [markdown]
# ## Pattern 3: Hierarchical DAG
#
# Multi-level workflow with parallel branches

# %%
@tool
def calculate_budget(amount: float, days: int) -> str:
    """Calculate daily budget"""
    return f"Daily budget: ${amount/days:.2f}"

# Multi-level agents
research_agent = Agent(
    name="researcher",
    system_prompt="Research travel options.",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0"),
    tools=[search_flights, check_weather]
)

budget_agent = Agent(
    name="budget",
    system_prompt="Analyze budget and costs.",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0"),
    tools=[calculate_budget]
)

report_agent = Agent(
    name="reporter",
    system_prompt="Create final travel report from research and budget analysis.",
    model=BedrockModel(model_id="us.amazon.nova-micro-v1:0")
)

# Build hierarchical DAG
dag_builder = GraphBuilder()
dag_builder.add_node(research_agent, "research")
dag_builder.add_node(budget_agent, "budget")
dag_builder.add_node(report_agent, "report")

# Parallel branches converging to report
dag_builder.add_edge("research", "report")
dag_builder.add_edge("budget", "report")

dag_builder.set_entry_point("research")

dag_builder.set_max_node_executions(10)

dag_graph = dag_builder.build()

# %%
# Execute DAG
result = dag_graph("Plan 5-day trip from BOS to SEA with $2000 budget")
print("/n/n")
print("="*120)
print("=== Final Answer ===")
print(result.results['report'].result)
# Out:
# <thinking> To plan a 5-day trip from Boston (BOS) to Seattle (SEA) within a $2000 budget, I need to find available flights, check the weather forecast for Seattle during the trip, and consider accommodations, transportation, and activities within the budget. However, I don't have direct access to accommodations, transportation, or activity information. I will start by finding flights that fit the budget.</thinking>
#
#
# Tool #1: search_flights
# <thinking> I have found three flights from Boston (BOS) to Seattle (SEA) within the budget: $299, $349, and $399. Next, I should check the weather forecast for Seattle to ensure the trip is well-planned. This information will help the user decide on the timing of the trip and what to pack.</thinking>
# Tool #2: check_weather
# <thinking> The weather forecast for Seattle is sunny with a temperature of 75°F, which is pleasant for a trip. However, the remaining details such as accommodation, local transportation, and activities are not covered by the available tools. Since I cannot provide this information directly, I will inform the user about the flight options and the weather forecast, and suggest that they might need to look into other resources for the remaining trip details.</thinking>
#
# Here are the flight options from Boston (BOS) to Seattle (SEA) within your budget:
# - Flight 1: $299
# - Flight 2: $349
# - Flight 3: $399
#
# The weather forecast for Seattle during your trip is sunny with a temperature of 75°F.
#
# For accommodation, local transportation, and activities, you might want to look into other resources or websites that can provide this information. Safe travels!**Final Travel Report: 5-Day Trip from BOS to SEA with $2000 Budget**
#
# ---
#
# **Overview:**
# This report details a planned 5-day trip from Boston (BOS) to Seattle (SEA) with a budget of $2000. The report includes flight options, weather forecast, and provides suggestions for further research on accommodations, local transportation, and activities.
#
# ---
#
# **Flight Options:**
# Based on the available information, here are the flight options from Boston (BOS) to Seattle (SEA) within your budget:
#
# 1. **Flight 1:**
#    - Price: $299
#    - Note: This is the most budget-friendly option.
#
# 2. **Flight 2:**
#    - Price: $349
#    - Note: Slightly more expensive but still within budget.
#
# 3. **Flight 3:**
#    - Price: $399
#    - Note: The most expensive option listed but offers some additional comfort or convenience.
#
# ---
#
# **Weather Forecast:**
# The weather forecast for Seattle during your trip is expected to be sunny with a comfortable temperature of 75°F. This pleasant weather is ideal for outdoor activities and sightseeing.
#
# ---
#
# **Further Research Areas:**
#
# **Accommodation:**
# To find suitable accommodations, consider the following options:
# - **Websites:** Expedia, Airbnb, Booking.com, Hotels.com
# - **Tips:** Look for hotels or lodgings near the city center for easy access to major attractions. Check for reviews and read about amenities offered.
#
# **Local Transportation:**
# For local transportation within Seattle, research the following:
# - **Public Transport:** Check the Seattle Transit System (ST) for buses, light rail, and streetcar options.
# - **Car Rentals:** Consider renting a car for more flexibility. Websites like Hertz, Avis, and Enterprise can be useful.
# - **Ride-Sharing:** Apps like Uber and Lyft are also widely used in Seattle.
#
# **Activities:**
# To plan activities and attractions, consider the following:
# - **Websites:** TripSavvy, Lonely Planet, Seattle.gov
# - **Popular Attractions:**
#   - Pike Place Market
#   - Space Needle
#   - Seattle Art Museum
#   - Chihuly Garden and Glass
#   - Mount Si for hiking
# - **Events:** Check local event calendars for festivals, concerts, or special exhibitions.
#
# ---
#
# **Budget Allocation:**
# Here’s a suggested breakdown of your $2000 budget:
#
# 1. **Flights:**
#    - Choose a flight from the options provided, which range from $299 to $399.
#
# 2. **Accommodation:**
#    - Allocate around $500 - $800 for 5 nights of lodging, depending on the type of accommodation you choose.
#
# 3. **Local Transportation:**
#    - Budget approximately $100 - $200 for public transport, car rentals, or ride-sharing services.
#
# 4. **Activities:**
#    - Allocate around $300 - $500 for sightseeing and local attractions.
#
# 5. **Miscellaneous:**
#    - Set aside $200 - $300 for meals, snacks, and any unexpected expenses.
#
# ---
#
# **Conclusion:**
# You have a well-structured budget and a clear starting point for your trip. With the flight options provided and the pleasant weather forecast, you are all set to enjoy your trip to Seattle. For the most accurate and detailed information on accommodations, local transport, and activities, it’s recommended to use the suggested resources and websites.
#
# Safe travels and enjoy your trip!
#
# ---
#
# **Note:** Should you require further assistance or specific recommendations, don’t hesitate to ask./n/n
# ========================================================================================================================
# === Final Answer ===
# **Final Travel Report: 5-Day Trip from BOS to SEA with $2000 Budget**
#
# ---
#
# **Overview:**
# This report details a planned 5-day trip from Boston (BOS) to Seattle (SEA) with a budget of $2000. The report includes flight options, weather forecast, and provides suggestions for further research on accommodations, local transportation, and activities.
#
# ---
#
# **Flight Options:**
# Based on the available information, here are the flight options from Boston (BOS) to Seattle (SEA) within your budget:
#
# 1. **Flight 1:**
#    - Price: $299
#    - Note: This is the most budget-friendly option.
#
# 2. **Flight 2:**
#    - Price: $349
#    - Note: Slightly more expensive but still within budget.
#
# 3. **Flight 3:**
#    - Price: $399
#    - Note: The most expensive option listed but offers some additional comfort or convenience.
#
# ---
#
# **Weather Forecast:**
# The weather forecast for Seattle during your trip is expected to be sunny with a comfortable temperature of 75°F. This pleasant weather is ideal for outdoor activities and sightseeing.
#
# ---
#
# **Further Research Areas:**
#
# **Accommodation:**
# To find suitable accommodations, consider the following options:
# - **Websites:** Expedia, Airbnb, Booking.com, Hotels.com
# - **Tips:** Look for hotels or lodgings near the city center for easy access to major attractions. Check for reviews and read about amenities offered.
#
# **Local Transportation:**
# For local transportation within Seattle, research the following:
# - **Public Transport:** Check the Seattle Transit System (ST) for buses, light rail, and streetcar options.
# - **Car Rentals:** Consider renting a car for more flexibility. Websites like Hertz, Avis, and Enterprise can be useful.
# - **Ride-Sharing:** Apps like Uber and Lyft are also widely used in Seattle.
#
# **Activities:**
# To plan activities and attractions, consider the following:
# - **Websites:** TripSavvy, Lonely Planet, Seattle.gov
# - **Popular Attractions:**
#   - Pike Place Market
#   - Space Needle
#   - Seattle Art Museum
#   - Chihuly Garden and Glass
#   - Mount Si for hiking
# - **Events:** Check local event calendars for festivals, concerts, or special exhibitions.
#
# ---
#
# **Budget Allocation:**
# Here’s a suggested breakdown of your $2000 budget:
#
# 1. **Flights:**
#    - Choose a flight from the options provided, which range from $299 to $399.
#
# 2. **Accommodation:**
#    - Allocate around $500 - $800 for 5 nights of lodging, depending on the type of accommodation you choose.
#
# 3. **Local Transportation:**
#    - Budget approximately $100 - $200 for public transport, car rentals, or ride-sharing services.
#
# 4. **Activities:**
#    - Allocate around $300 - $500 for sightseeing and local attractions.
#
# 5. **Miscellaneous:**
#    - Set aside $200 - $300 for meals, snacks, and any unexpected expenses.
#
# ---
#
# **Conclusion:**
# You have a well-structured budget and a clear starting point for your trip. With the flight options provided and the pleasant weather forecast, you are all set to enjoy your trip to Seattle. For the most accurate and detailed information on accommodations, local transport, and activities, it’s recommended to use the suggested resources and websites.
#
# Safe travels and enjoy your trip!
#
# ---
#
# **Note:** Should you require further assistance or specific recommendations, don’t hesitate to ask.

# %% [markdown]
# ## Observability: Inspect Graph Execution

# %%
# Detailed execution trace
print("=== Graph Execution Details ===")
print(f"Total nodes executed: {len(result.execution_order)}")
print(f"\nExecution path:")

for i, node in enumerate(result.execution_order, 1):
    print(f"\n{i}. Node: {node.node_id}")
    print(f"   Response length: {len(str(node.result.result))} chars")
    print(f"   Preview: {str(node.result.result)[:150]}...")
# Out:
# === Graph Execution Details ===
# Total nodes executed: 2
#
# Execution path:
#
# 1. Node: research
#    Response length: 858 chars
#    Preview: <thinking> The weather forecast for Seattle is sunny with a temperature of 75°F, which is pleasant for a trip. However, the remaining details such as ...
#
# 2. Node: report
#    Response length: 3248 chars
#    Preview: **Final Travel Report: 5-Day Trip from BOS to SEA with $2000 Budget**
#
# ---
#
# **Overview:**
# This report details a planned 5-day trip from Boston (BOS) t...

# %% [markdown]
# ## Compare Patterns

# %%
import time

query = "Find flights from NYC to LAX"

patterns = [
    ("Sequential", sequential_graph),
    ("Star", star_graph),
    ("DAG", dag_graph)
]

patterns_metrics = {
    "Sequential": {},
    "Star": {},
    "DAG": {}
}

for name, graph in patterns:
    start = time.time()
    result = graph(query)
    duration = time.time() - start

    metrics = {
        "Execution time": f"{duration:.2f}s",
        "Nodes executed": {result.completed_nodes},
        "Path": {' → '.join([n.node_id for n in result.execution_order])}
    }

    patterns_metrics[name] = metrics


print("/n/n")
print("="*120)
print("=== Pattern Comparison ===")
print(patterns_metrics)
# Out:
# To find flights from NYC (New York City) to LAX (Los Angeles International Airport), follow these steps:
#
# 1. Open a web browser on your computer or mobile device.
# 2. Go to a reputable flight search website, such as Google Flights, Expedia, Kayak, or Skyscanner.
# 3. In the departure city field, enter "NYC" or select New York City from the dropdown list.
# 4. In the destination city field, enter "LAX" or select Los Angeles International Airport from the dropdown list.
# 5. Select your desired travel dates for the departure and return (if applicable).
# 6. Click on the search button to view the available flight options.
# 7. Review the search results and compare flights based on factors such as departure and arrival times, duration, price, and airline preferences.
# 8. Choose the flight that best suits your needs and click on it for more details.
# 9. If you wish to proceed with booking, follow the instructions provided on the website to complete the reservation.
#
# Remember to consider factors like layovers, departure and arrival terminals, and any additional fees when comparing flights.<thinking> The original task was to find flights from NYC (New York City) to LAX (Los Angeles International Airport).
#
# I have already completed the task using the appropriate tool:
#
# For the flight search, I used the "search_flights" tool, which returned 3 flights with prices: $299, $349, $399.
#
# The task is now complete, and all the necessary information has been provided to the user.</thinking>
#
# Here are the results for your request:
#
# **Flights from NYC to LAX:**
# - Found 3 flights with prices: $299, $349, $399
#
# If you need any further assistance, feel free to ask!Based on the synthesized execution results, here is a final recommendation for your flight search from NYC to LAX:
#
# ---
#
# **Flights from NYC to LAX:**
# You have three flight options available from New York City to Los Angeles International Airport (LAX):
# 1. Flight with a price of **$299**
# 2. Flight with a price of **$349**
# 3. Flight with a price of **$399**
#
# If you need further assistance with booking any of these flights or any other details, feel free to ask!
#
# ---
#
# Thank you for reaching out, and have a great trip ahead!To find flights from New York City (NYC) to Los Angeles (LAX), we need to gather some specific details to narrow down your search. Here are the details we need:
#
# ### Departure and Return Dates
# 1. **Departure Date**: When do you plan to depart from NYC?
# 2. **Return Date**: When do you plan to return to NYC?
#
# ### Preferences
# 1. **Direct Flights**: Would you prefer direct flights, or are you open to flights with connections?
# 2. **Specific Airlines**: Are there any particular airlines you prefer or wish to avoid?
# 3. **Time of Day for Departure**: Do you have a preferred time of day for your departure (e.g., morning, afternoon, evening)?
# 4. **Budget**: Do you have a specific budget in mind for your flights?
#
# Once I have this information, I can guide you on how to use online travel websites to find the best flights that meet your needs. Here’s a quick guide on how to search for flights using popular travel websites:
#
# ### Using Online Travel Websites
#
# #### 1. **Google Flights**
#    - Go to [Google Flights](https://www.google.com/flights).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search Flights".
#    - Use filters to narrow down to your preferred options.
#
# #### 2. **Expedia**
#    - Go to [Expedia](https://www.expedia.com).
#    - Enter "New York City" in the "From" field and "Los Angeles" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and use filters to refine your results.
#
# #### 3. **Kayak**
#    - Go to [Kayak](https://www.kayak.com).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and refine your results with additional filters.
#
# ### Example Search:
#
# Let’s say you want to travel from NYC to LAX on October 15th, 2023, with a return date of October 20th, 2023. Here’s how you can perform the search on Google Flights:
#
# 1. Open [Google Flights](https://www.google.com/flights).
# 2. In the "From" field, type "NYC".
# 3. In the "To" field, type "LAX".
# 4. Enter "10/15/2023" as the departure date and "10/20/2023" as the return date.
# 5. Click on "Search Flights".
# 6. Use the filters to narrow down to your preferred options.
#
# ### Tips:
#
# - **Flexible Dates**: If your travel dates are flexible, you can use the "Flexible Dates" feature to find the cheapest days to fly.
# - **Price Alerts**: Set up price alerts for specific routes to get notified when prices drop.
# - **Budget Airlines**: Consider budget airlines if cost is a primary concern.
#
# Please provide the specific details for your trip, and I'll be happy to guide you further!<thinking> The user has not yet provided the specific details needed to search for flights from NYC to LAX.<thinking> To proceed, I will ask the user for the departure and return dates, as well as any preferences To proceed effectively, I need to gather specific details from the user regarding their flight search from NYC to they may have regarding direct flights, specific airlines, departure times, and budget.</thinking>
#
# To find LAX. This includes departure and return dates, preferences for direct flights or connections, specific airlines, flights from New York City (NYC) to Los Angeles (LAX), please provide the following details:
#
#  preferred departure times, and budget constraints. Once I have this information, I can guide the user on1. **Departure and Return Dates**:
#    - **Departure Date**: When how to use online travel websites to find the best flights that meet their needs do you plan.</ to depart from NYCthinking>
#
# To find?
#    - **Return Date**: When do you plan to return to NYC?
#
# 2. **Preferences**:
#  flights    from New York- ** CityDirect ( Flights**: Would youNYC) to prefer direct Los Angeles (LAX), we need to gather some specific flights, or are you open to flights with connections?
#    - **Specific Airlines**: Are there any details to narrow down your search. Here are the details we need:
#
# ### Departure and Return Dates
#  particular airlines you prefer or wish to avoid?
#    - **Time of Day for Departure**: Do you1. **Departure Date**: When do you plan to depart from NYC?
# 2. ** have a preferred time of day for your departure (e.g., morning, afternoon, evening)?
# Return Date**: When do you plan to return to NYC?
#
# ### Preferences
# 1. **Direct Flights   - **Budget**: Do you have a specific budget in mind for your flights?
#
# Once I have**: Would you prefer direct flights, or are you open to flights with connections?
# 2. **Specific this information, I can guide you on how to use online travel websites to find the best flights that meet your needs. Airlines**: Are there any particular airlines you prefer or wish to avoid?
# 3. **Time of Day for Departure**: Do you have a preferred time of day for your departure (e.g., morning, afternoon, evening)?
# 4. **Budget**: Do you have a specific budget in mind for your flights?
#
# Once I have this information, I can guide you on how to use online travel websites to find the best flights that meet your needs. Here’s a quick guide on how to search for flights using popular travel websites:
#
# ### Using Online Travel Websites
#
# #### 1. **Google Flights**
#    - Go to [Google Flights](https://www.google.com/flights).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search Flights".
#    - Use filters to narrow down to your preferred options.
#
# #### 2. **Expedia**
#    - Go to [Expedia](https://www.expedia.com).
#    - Enter "New York City" in the "From" field and "Los Angeles" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and use filters to refine your results.
#
# #### 3. **Kayak**
#    - Go to [Kayak](https://www.kayak.com).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and refine your results with additional filters.
#
# ### Example Search:
#
# Let’s say you want to travel from NYC to LAX on October 15th, 2023, with a return date of October 20th, 2023. Here’s how you can perform the search on Google Flights:
#
# 1. Open [Google Flights](https://www.google.com/flights).
# 2. In the "From" field, type "NYC".
# 3. In the "To" field, type "LAX".
# 4. Enter "10/15/2023" as the departure date and "10/20/2023" as the return date.
# 5. Click on "Search Flights".
# 6. Use the filters to narrow down to your preferred options.
#
# ### Tips:
#
# - **Flexible Dates**: If your travel dates are flexible, you can use the "Flexible Dates" feature to find the cheapest days to fly.
# - **Price Alerts**: Set up price alerts for specific routes to get notified when prices drop.
# - **Budget Airlines**: Consider budget airlines if cost is a primary concern.
#
# Please provide the specific details for your trip, and I'll be happy to guide you further!To find flights from New York City (NYC) to Los Angeles (LAX), we need to gather some specific details to narrow down your search. Here are the details we need:
#
# ### Departure and Return Dates
# 1. **Departure Date**: When do you plan to depart from NYC?
# 2. **Return Date**: When do you plan to return to NYC?
#
# ### Preferences
# 1. **Direct Flights**: Would you prefer direct flights, or are you open to flights with connections?
# 2. **Specific Airlines**: Are there any particular airlines you prefer or wish to avoid?
# 3. **Time of Day for Departure**: Do you have a preferred time of day for your departure (e.g., morning, afternoon, evening)?
# 4. **Budget**: Do you have a specific budget in mind for your flights?
#
# Once I have this information, I can guide you on how to use online travel websites to find the best flights that meet your needs. Here’s a quick guide on how to search for flights using popular travel websites:
#
# ### Using Online Travel Websites
#
# #### 1. **Google Flights**
#    - Go to [Google Flights](https://www.google.com/flights).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search Flights".
#    - Use filters to narrow down to your preferred options.
#
# #### 2. **Expedia**
#    - Go to [Expedia](https://www.expedia.com).
#    - Enter "New York City" in the "From" field and "Los Angeles" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and use filters to refine your results.
#
# #### 3. **Kayak**
#    - Go to [Kayak](https://www.kayak.com).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and refine your results with additional filters.
#
# ### Example Search:
#
# Let’s say you want to travel from NYC to LAX on October 15th, 2023, with a return date of October 20th, 2023. Here’s how you can perform the search on Google Flights:
#
# 1. Open [Google Flights](https://www.google.com/flights).
# 2. In the "From" field, type "NYC".
# 3. In the "To" field, type "LAX".
# 4. Enter "10/15/2023" as the departure date and "10/20/2023" as the return date.
# 5. Click on "Search Flights".
# 6. Use the filters to narrow down to your preferred options.
#
# ### Tips:
#
# - **Flexible Dates**: If your travel dates are flexible, you can use the "Flexible Dates" feature to find the cheapest days to fly.
# - **Price Alerts**: Set up price alerts for specific routes to get notified when prices drop.
# - **Budget Airlines**: Consider budget airlines if cost is a primary concern.
#
# Please provide the specific details for your trip, and I'll be happy to guide you further!<thinking> The user has not yet provided the specific details needed to search for flights from NYC to LAX. To proceed, I will ask the user for the departure and return dates, as well as any preferences<thinking> they may have regarding direct flights, specific airlines, departure times, and budget.</thinking>
#
# To find To proceed effectively, I need to gather specific details from the user regarding their flight search from NYC to flights from New York City (NYC) to Los Angeles (LAX), please provide the following details:
#
#  LAX. This includes departure and return dates, preferences for direct flights or connections, specific airlines,1. **Departure and Return Dates**:
#    - **Departure Date**: When preferred departure times, and budget constraints. Once I have this information, I can guide the user on do you plan to depart from NYC?
#    - **Return Date**: When do you plan to return how to use online travel websites to find the best flights that meet their needs.</thinking>
#
# To find to NYC?
#
# 2. **Preferences**:
#    - **Direct Flights**: Would you prefer direct flights from New York City (NYC) to Los Angeles (LAX), we need to gather some specific flights, or are you open to flights with connections?
#    - **Specific Airlines**: Are there any particular airlines details to narrow you prefer or wish to avoid?
#    - **Time down of Day for Departure**: your search. Here Do you are the details we need:
#
# ### Departure and Return Dates
#  have a preferred time of day for your departure (e.g., morning, afternoon, evening)?
# 1. **Departure Date**: When do you plan to depart from NYC?
# 2. **   - **Budget**: Do you have a specific budget in mind for your flights?
#
# Once I haveReturn Date**: When do you plan to return to NYC?
#
# ### Preferences
# 1. **Direct Flights this information, I can guide you on how to use online travel websites to find the best flights that**: Would you prefer direct flights, or meet your are you open to flights with connections?
# 2. ** needs.Specific Airlines**: Are there any particular airlines you prefer or wish to avoid?
# 3. **Time of Day for Departure**: Do you have a preferred time of day for your departure (e.g., morning, afternoon, evening)?
# 4. **Budget**: Do you have a specific budget in mind for your flights?
#
# Once I have this information, I can guide you on how to use online travel websites to find the best flights that meet your needs. Here’s a quick guide on how to search for flights using popular travel websites:
#
# ### Using Online Travel Websites
#
# #### 1. **Google Flights**
#    - Go to [Google Flights](https://www.google.com/flights).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search Flights".
#    - Use filters to narrow down to your preferred options.
#
# #### 2. **Expedia**
#    - Go to [Expedia](https://www.expedia.com).
#    - Enter "New York City" in the "From" field and "Los Angeles" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and use filters to refine your results.
#
# #### 3. **Kayak**
#    - Go to [Kayak](https://www.kayak.com).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and refine your results with additional filters.
#
# ### Example Search:
#
# Let’s say you want to travel from NYC to LAX on October 15th, 2023, with a return date of October 20th, 2023. Here’s how you can perform the search on Google Flights:
#
# 1. Open [Google Flights](https://www.google.com/flights).
# 2. In the "From" field, type "NYC".
# 3. In the "To" field, type "LAX".
# 4. Enter "10/15/2023" as the departure date and "10/20/2023" as the return date.
# 5. Click on "Search Flights".
# 6. Use the filters to narrow down to your preferred options.
#
# ### Tips:
#
# - **Flexible Dates**: If your travel dates are flexible, you can use the "Flexible Dates" feature to find the cheapest days to fly.
# - **Price Alerts**: Set up price alerts for specific routes to get notified when prices drop.
# - **Budget Airlines**: Consider budget airlines if cost is a primary concern.
#
# Please provide the specific details for your trip, and I'll be happy to guide you further!To find flights from New York City (NYC) to Los Angeles (LAX), we need to gather some specific details to narrow down your search. Here are the details we need:
#
# ### Departure and Return Dates
# 1. **Departure Date**: When do you plan to depart from NYC?
# 2. **Return Date**: When do you plan to return to NYC?
#
# ### Preferences
# 1. **Direct Flights**: Would you prefer direct flights, or are you open to flights with connections?
# 2. **Specific Airlines**: Are there any particular airlines you prefer or wish to avoid?
# 3. **Time of Day for Departure**: Do you have a preferred time of day for your departure (e.g., morning, afternoon, evening)?
# 4. **Budget**: Do you have a specific budget in mind for your flights?
#
# Once I have this information, I can guide you on how to use online travel websites to find the best flights that meet your needs. Here’s a quick guide on how to search for flights using popular travel websites:
#
# ### Using Online Travel Websites
#
# #### 1. **Google Flights**
#    - Go to [Google Flights](https://www.google.com/flights).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search Flights".
#    - Use filters to narrow down to your preferred options.
#
# #### 2. **Expedia**
#    - Go to [Expedia](https://www.expedia.com).
#    - Enter "New York City" in the "From" field and "Los Angeles" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and use filters to refine your results.
#
# #### 3. **Kayak**
#    - Go to [Kayak](https://www.kayak.com).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and refine your results with additional filters.
#
# ### Example Search:
#
# Let’s say you want to travel from NYC to LAX on October 15th, 2023, with a return date of October 20th, 2023. Here’s how you can perform the search on Google Flights:
#
# 1. Open [Google Flights](https://www.google.com/flights).
# 2. In the "From" field, type "NYC".
# 3. In the "To" field, type "LAX".
# 4. Enter "10/15/2023" as the departure date and "10/20/2023" as the return date.
# 5. Click on "Search Flights".
# 6. Use the filters to narrow down to your preferred options.
#
# ### Tips:
#
# - **Flexible Dates**: If your travel dates are flexible, you can use the "Flexible Dates" feature to find the cheapest days to fly.
# - **Price Alerts**: Set up price alerts for specific routes to get notified when prices drop.
# - **Budget Airlines**: Consider budget airlines if cost is a primary concern.
#
# Please provide the specific details for your trip, and I'll be happy to guide you further!<thinking> The user has not yet provided the specific details needed to search for flights from NYC to LAX. To proceed, I will ask the user for the departure and return dates, as well as any preferences they may have regarding direct flights, specific airlines, departure times, and budget.</thinking>
#
# To find<thinking> flights from New York City (NYC) to Los Angeles (LAX), please provide the following details:
#
#  To proceed effectively, I need to gather specific details from the user regarding their flight search from NYC to1. **Departure and Return Dates**:
#    - **Departure Date**: When LAX. This includes departure and return dates, preferences for direct flights or connections, specific airlines, do you plan to depart from NYC?
#    - **Return Date**: When do you plan to return preferred departure times, and budget constraints. Once I have this information, I can guide the user on to NYC?
#
# 2. **Preferences**:
#    - **Direct Flights**: Would you prefer direct how to use online travel websites to find the best flights that meet their needs.</thinking>
#
# To find flights, or are you open to flights with connections?
#    - **Specific Airlines**: Are there any particular airlines you prefer or wish to avoid?
#    - **Time of Day flights for Departure from New**: York City Do ( youNYC) to Los Angeles (LAX), we need to gather some specific have a preferred time of day for your departure (e.g., morning, afternoon, evening)?
#  details to narrow down your search. Here are the details we need:
#
# ### Departure and Return Dates
#    - **Budget**: Do you have a specific budget in mind for your flights?
#
# Once I have1. **Departure Date**: When do you plan to depart from NYC?
# 2. ** this information, I can guide you on how to use online travel websites to find the best flights that meet your needs.Return Date**: When do you plan to return to NYC?
#
# ### Preferences
# 1. **Direct Flights**: Would you prefer direct flights, or are you open to flights with connections?
# 2. **Specific Airlines**: Are there any particular airlines you prefer or wish to avoid?
# 3. **Time of Day for Departure**: Do you have a preferred time of day for your departure (e.g., morning, afternoon, evening)?
# 4. **Budget**: Do you have a specific budget in mind for your flights?
#
# Once I have this information, I can guide you on how to use online travel websites to find the best flights that meet your needs. Here’s a quick guide on how to search for flights using popular travel websites:
#
# ### Using Online Travel Websites
#
# #### 1. **Google Flights**
#    - Go to [Google Flights](https://www.google.com/flights).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search Flights".
#    - Use filters to narrow down to your preferred options.
#
# #### 2. **Expedia**
#    - Go to [Expedia](https://www.expedia.com).
#    - Enter "New York City" in the "From" field and "Los Angeles" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and use filters to refine your results.
#
# #### 3. **Kayak**
#    - Go to [Kayak](https://www.kayak.com).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and refine your results with additional filters.
#
# ### Example Search:
#
# Let’s say you want to travel from NYC to LAX on October 15th, 2023, with a return date of October 20th, 2023. Here’s how you can perform the search on Google Flights:
#
# 1. Open [Google Flights](https://www.google.com/flights).
# 2. In the "From" field, type "NYC".
# 3. In the "To" field, type "LAX".
# 4. Enter "10/15/2023" as the departure date and "10/20/2023" as the return date.
# 5. Click on "Search Flights".
# 6. Use the filters to narrow down to your preferred options.
#
# ### Tips:
#
# - **Flexible Dates**: If your travel dates are flexible, you can use the "Flexible Dates" feature to find the cheapest days to fly.
# - **Price Alerts**: Set up price alerts for specific routes to get notified when prices drop.
# - **Budget Airlines**: Consider budget airlines if cost is a primary concern.
#
# Please provide the specific details for your trip, and I'll be happy to guide you further!To find flights from New York City (NYC) to Los Angeles (LAX), we need to gather some specific details to narrow down your search. Here are the details we need:
#
# ### Departure and Return Dates
# 1. **Departure Date**: When do you plan to depart from NYC?
# 2. **Return Date**: When do you plan to return to NYC?
#
# ### Preferences
# 1. **Direct Flights**: Would you prefer direct flights, or are you open to flights with connections?
# 2. **Specific Airlines**: Are there any particular airlines you prefer or wish to avoid?
# 3. **Time of Day for Departure**: Do you have a preferred time of day for your departure (e.g., morning, afternoon, evening)?
# 4. **Budget**: Do you have a specific budget in mind for your flights?
#
# Once I have this information, I can guide you on how to use online travel websites to find the best flights that meet your needs. Here’s a quick guide on how to search for flights using popular travel websites:
#
# ### Using Online Travel Websites
#
# #### 1. **Google Flights**
#    - Go to [Google Flights](https://www.google.com/flights).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search Flights".
#    - Use filters to narrow down to your preferred options.
#
# #### 2. **Expedia**
#    - Go to [Expedia](https://www.expedia.com).
#    - Enter "New York City" in the "From" field and "Los Angeles" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and use filters to refine your results.
#
# #### 3. **Kayak**
#    - Go to [Kayak](https://www.kayak.com).
#    - Enter "NYC" in the "From" field and "LAX" in the "To" field.
#    - Input your travel dates.
#    - Click on "Search" and refine your results with additional filters.
#
# ### Example Search:
#
# Let’s say you want to travel from NYC to LAX on October 15th, 2023, with a return date of October 20th, 2023. Here’s how you can perform the search on Google Flights:
#
# 1. Open [Google Flights](https://www.google.com/flights).
# 2. In the "From" field, type "NYC".
# 3. In the "To" field, type "LAX".
# 4. Enter "10/15/2023" as the departure date and "10/20/2023" as the return date.
# 5. Click on "Search Flights".
# 6. Use the filters to narrow down to your preferred options.
#
# ### Tips:
#
# - **Flexible Dates**: If your travel dates are flexible, you can use the "Flexible Dates" feature to find the cheapest days to fly.
# - **Price Alerts**: Set up price alerts for specific routes to get notified when prices drop.
# - **Budget Airlines**: Consider budget airlines if cost is a primary concern.
#
# Please provide the specific details for your trip, and I'll be happy to guide you further!<thinking> The user has once again requested flight information for the NYC to LAX route. Since I've already provided this information multiple times, I will now simply refer the user to the previously given options without restating them. If the user needs further details or has a different request, I will be prepared to assist accordingly.</thinking>
#
# As previously shared, here are the flight options from New York City (NYC) to Los Angeles (LAX) within your budget:
# - Flight 1: $299
# - Flight 2: $349
# - Flight 3: $399
#
# If you need more information or have another request, feel free to ask!**Final Travel Report: Summary of Flight Options from NYC to LAX**
#
# ---
#
# **Overview:**
# This report serves as a concise reminder of the previously provided flight options from New York City (NYC) to Los Angeles (LAX) within your budget, ensuring that you have the necessary information without restating all the details multiple times.
#
# ---
#
# **Flight Options:**
#
# 1. **Flight 1:**
#    - **Price:** $299
#    - **Note:** This is the most budget-friendly option available.
#
# 2. **Flight 2:**
#    - **Price:** $349
#    - **Note:** Slightly more expensive but still within your budget.
#
# 3. **Flight 3:**
#    - **Price:** $399
#    - **Note:** This is the most expensive option listed, potentially offering more comfort or convenience.
#
# ---
#
# **Additional Context:**
#
# I understand that you have requested this information multiple times. To streamline our communication, I'm simply referring you to the previously provided options. If you need more detailed information about any of these flights, such as specific schedules, layovers, or additional services, or if you have another request or need assistance with a different travel plan, please let me know.
#
# ---
#
# **Next Steps:**
#
# - **More Details:** If you require further specifics about any of the flights, specify your needs.
# - **Additional Requests:** Should you need help with accommodations, local transportation, activities, or any other travel-related queries, feel free to ask.
#
# ---
#
# **Conclusion:**
# You have three flight options from NYC to LAX within your budget. With this information, you can make an informed decision based on your preferences and travel plans.
#
# Safe travels and enjoy your journey!
#
# ---
#
# **Note:** Should you need any more help or specific recommendations, don’t hesitate to ask./n/n
# ========================================================================================================================
# === Pattern Comparison ===
# {'Sequential': {'Execution time': '3.27s', 'Nodes executed': {3}, 'Path': {'planner → executor → synthesizer'}}, 'Star': {'Execution time': '41.00s', 'Nodes executed': {3}, 'Path': {'coordinator → flights → weather → coordinator → flights → weather → coordinator → flights → weather → coordinator'}}, 'DAG': {'Execution time': '2.30s', 'Nodes executed': {2}, 'Path': {'research → report'}}}

# %%
from pprint import pprint
print("/n/n")
print("="*120)
print("=== Pattern Comparison ===")
pprint(patterns_metrics)
# Out:
# /n/n
# ========================================================================================================================
# === Pattern Comparison ===
# {'DAG': {'Execution time': '2.30s',
#          'Nodes executed': {2},
#          'Path': {'research → report'}},
#  'Sequential': {'Execution time': '3.27s',
#                 'Nodes executed': {3},
#                 'Path': {'planner → executor → synthesizer'}},
#  'Star': {'Execution time': '41.00s',
#           'Nodes executed': {3},
#           'Path': {'coordinator → flights → weather → coordinator → flights → '
#                    'weather → coordinator → flights → weather → coordinator'}}}
